# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
import json

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create endpoint URL with each city
city_url = f"{url}appid={weather_api_key}&q={city}&units=metric"

city_weather = requests.get(city_url)
city_json = city_weather.json()
city_weather = requests.get(city_url)
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
city_weather
# Out:
# <Response [200]>

# %%
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=d5adda31752abc852038f232624d9408&q=kununurra&units=metric'

# %%
city_json["dt"]
# Out:
# 1717649681

# %%
print(json.dumps(city_json, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -15.7667,
#         "lon": 128.7333
#     },
#     "dt": 1717649681,
#     "id": 2068110,
#     "main": {
#         "feels_like": 25.99,
#         "humidity": 31,
#         "pressure": 1017,
#         "temp": 25.99,
#         "temp_max": 25.99,
#         "temp_min": 25.99
#     },
#     "name": "Kununurra",
#     "sys": {
#         "country": "AU",
#         "id": 9587,
#         "sunrise": 1717624032,
#         "sunset": 1717664434,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 120,
#         "speed": 6.17
#     }
# }

# %%
# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url)
        city_json = city_weather.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_json["coord"]["lat"]
        city_lng = city_json["coord"]["lon"]
        city_max_temp = city_json["main"]["temp_max"]
        city_humidity = city_json["main"]["humidity"]
        city_clouds = city_json["clouds"]["all"]
        city_wind = city_json["wind"]["speed"]
        city_country = city_json["sys"]["country"]
        city_date = city_json["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
        
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 43 of Set 12 | albany
# Processing Record 44 of Set 12 | saipan
# Processing Record 45 of Set 12 | rukban
# City not found. Skipping...
# Processing Record 46 of Set 12 | port-aux-francais
# Processing Record 47 of Set 12 | queenstown
# Processing Record 48 of Set 12 | invercargill
# Processing Record 49 of Set 12 | baturaja
# Processing Record 50 of Set 12 | nar'yan-mar
# Processing Record 51 of Set 12 | hamilton
# Processing Record 52 of Set 12 | adamstown
# Processing Record 53 of Set 12 | waitangi
# Processing Record 54 of Set 12 | sotouboua
# Processing Record 55 of Set 12 | skuodas
# Processing Record 56 of Set 12 | papatowai
# Processing Record 57 of Set 12 | changqing
# Processing Record 58 of Set 12 | mossel bay
# Processing Record 59 of Set 12 | port alfred
# Processing Record 60 of Set 12 | longyearbyen
# Processing Record 61 of Set 12 | bredasdorp
# Processing Record 62 of Set 12 | igarka
# Processing Record 63 of Set 12 | kodiak
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
len(city_data_df)
# Out:
# 565

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             albany  42.6001  -73.9662     21.42        85         100
# 1             saipan  15.1355  145.7010     32.39        62          40
# 2  port-aux-francais -49.3500   70.2167      2.25        74          24
# 3         queenstown -31.8976   26.8753      6.01        54           0
# 4       invercargill -46.4000  168.3500     11.12        97         100
#
#    Wind Speed Country        Date
# 0        2.60      US  1717649681
# 1        7.72      MP  1717649681
# 2       18.42      TF  1717649682
# 3        2.66      ZA  1717649682
# 4        0.45      NZ  1717649637

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   albany  42.6001  -73.9662     21.42        85         100
# 1                   saipan  15.1355  145.7010     32.39        62          40
# 2        port-aux-francais -49.3500   70.2167      2.25        74          24
# 3               queenstown -31.8976   26.8753      6.01        54           0
# 4             invercargill -46.4000  168.3500     11.12        97         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      US  1717649681
# 1              7.72      MP  1717649681
# 2             18.42      TF  1717649682
# 3              2.66      ZA  1717649682
# 4              0.45      NZ  1717649637

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Temperature")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
from scipy import stats

def plot_regressions (x_values, y_values, xlabel, ylabel, hemisphere):
    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

     # Create Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.title(f"{hemisphere} Hemisphere - {xlabel} vs {ylabel}")
    
    # Label plot and annotate the line equation
    plt.xlabel('Latitude')
    plt.ylabel(ylabel)
    plt.annotate(line_eq,(0,0),fontsize=15,color="black")
        
    # Print r value
    print(f"The r-value is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"the correlation between both factors is {round(correlation[0],2)}")
    
    # Show plot
    return plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             albany  42.6001  -73.9662     21.42        85         100
# 1             saipan  15.1355  145.7010     32.39        62          40
# 6        nar'yan-mar  67.6713   53.0870      5.06        86          96
# 7           hamilton  39.1834  -84.5333     22.47        94          75
# 10         sotouboua   8.5667    0.9833     21.95        89         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      US  1717649681
# 1              7.72      MP  1717649681
# 6              4.47      RU  1717649682
# 7              3.09      US  1717649529
# 10             0.21      TG  1717649683

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        port-aux-francais -49.3500   70.2167      2.25        74          24
# 3               queenstown -31.8976   26.8753      6.01        54           0
# 4             invercargill -46.4000  168.3500     11.12        97         100
# 5                 baturaja  -4.1333  104.1667     32.68        55          81
# 8                adamstown -25.0660 -130.1015     22.15        77          34
#
#          Wind Speed Country        Date
# City_ID
# 2             18.42      TF  1717649682
# 3              2.66      ZA  1717649682
# 4              0.45      NZ  1717649637
# 5              1.36      ID  1717649682
# 8              5.59      PN  1717649682

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_regressions(x_values, y_values, "Latitude", "Temperature C", "Northern")
# Out:
# The r-value is: 0.6012602538031678
# the correlation between both factors is -0.78

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_regressions(x_values, y_values, "Latitude", "Temperature C", "Southern")
# Out:
# The r-value is: 0.5514679373227888
# the correlation between both factors is 0.74

# %%
print("Discussion about the linear relationship: Tempuratures in both the Northern and Southern Hemispheres are higher the closer to the equater or Latitude 0.")
# Out:
# Discussion about the linear relationship: Tempuratures in both the Northern and Southern Hemispheres are higher the closer to the equater or Latitude 0.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_regressions(x_values, y_values, "Latitude", "Humidity", "Northern")
# Out:
# The r-value is: 1.069736731532419e-07
# the correlation between both factors is -0.0

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_regressions(x_values, y_values, "Latitude", "Humidity", "Southern")
# Out:
# The r-value is: 0.01043656733448788
# the correlation between both factors is -0.1

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_regressions(x_values, y_values, "Latitude", "Cloudiness", "Northern")
# Out:
# The r-value is: 0.00011860193431562758
# the correlation between both factors is 0.01

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_regressions(x_values, y_values, "Latitude", "Cloudiness", "Southern")
# Out:
# The r-value is: 0.0034295726414872107
# the correlation between both factors is -0.06

# %%
print("Discussion about the linear relationship: For both Humidity and Cloudiness between the Northern and Southern Hemispheres there is very little to no correlation.")
# Out:
# Discussion about the linear relationship: For both Humidity and Cloudiness between the Northern and Southern Hemispheres there is very little to no correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_regressions(x_values, y_values, "Latitude", "Wind Speed", "Northern")
# Out:
# The r-value is: 0.003644586914716588
# the correlation between both factors is 0.06

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_regressions(x_values, y_values, "Latitude", "Wind Speed", "Southern")
# Out:
# The r-value is: 0.050644499694777155
# the correlation between both factors is -0.23

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
print("Discussion about the linear relationship: Wind Speed between the Northern and Southern Hemispheres seems to be similar for latitudes near the equater.")
# Out:
# Discussion about the linear relationship: Wind Speed between the Northern and Southern Hemispheres seems to be similar for latitudes near the equater.
